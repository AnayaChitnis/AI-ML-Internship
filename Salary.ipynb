# %%
import pandas as pd #pip install pandas
import numpy as np 
#pip install -U scikit-learn
import pickle
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv(r'C:/Users/siddh/OneDrive/Desktop/Git/anaya/Salary.csv')
df.head(3)
# Out:
#    Calendar Year  Agency Name       Position Title     Employee Name  \
# 0           2024  AGRICULTURE           ACCOUNTANT     OTTO, BRIDGET
# 1           2024  AGRICULTURE  ACCOUNTS SUPERVISOR  STOEHR, KALEB J.
# 2           2024  AGRICULTURE  ACCOUNTS SUPERVISOR    WALKER, JOE E.
#
#    YTD Gross Pay
# 0       55819.64
# 1       59947.10
# 2        8010.72

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        Calendar Year     Agency Name              Position Title  \
# 0               2024     AGRICULTURE                  ACCOUNTANT
# 1               2024     AGRICULTURE         ACCOUNTS SUPERVISOR
# 2               2024     AGRICULTURE         ACCOUNTS SUPERVISOR
# 3               2024     AGRICULTURE     ADMIN SUPPORT ASSISTANT
# 4               2024     AGRICULTURE     ADMIN SUPPORT ASSISTANT
# ...              ...             ...                         ...
# 72863           2024  TRANSPORTATION  TRANSPORTATION PROJECT MGR
# 72864           2024  TRANSPORTATION    URBAN TRAFFIC SUPERVISOR
# 72865           2024  TRANSPORTATION    URBAN TRAFFIC SUPERVISOR
# 72866           2024  TRANSPORTATION    URBAN TRAFFIC SUPERVISOR
# 72867           2024  TRANSPORTATION    URBAN TRAFFIC SUPERVISOR
#
#               Employee Name  YTD Gross Pay
# 0             OTTO, BRIDGET       55819.64
# 1          STOEHR, KALEB J.       59947.10
# ...

# %%
df.columns
# Out:
# Index(['Calendar Year', 'Agency Name', 'Position Title', 'Employee Name',
#        'YTD Gross Pay'],
#       dtype='object')

# %%
df.drop(columns= ['Employee Name'], inplace=True )

# %%
df.columns
# Out:
# Index(['Calendar Year', 'Agency Name', 'Position Title', 'YTD Gross Pay'], dtype='object')

# %%
df.head(3)
# Out:
#    Calendar Year  Agency Name       Position Title  YTD Gross Pay
# 0           2024  AGRICULTURE           ACCOUNTANT       55819.64
# 1           2024  AGRICULTURE  ACCOUNTS SUPERVISOR       59947.10
# 2           2024  AGRICULTURE  ACCOUNTS SUPERVISOR        8010.72

# %%
d = {"Calendar Year":"Year", "Agency Name":"Field","Position Title":"Post","YTD Gross Pay":"Salary"}
df.rename(columns= d , inplace=True )

# %%
df.head(3)
# Out:
#    Year        Field                 Post    Salary
# 0  2024  AGRICULTURE           ACCOUNTANT  55819.64
# 1  2024  AGRICULTURE  ACCOUNTS SUPERVISOR  59947.10
# 2  2024  AGRICULTURE  ACCOUNTS SUPERVISOR   8010.72

# %%
df['Year'].unique
# Out:
# <bound method Series.unique of 0        2024
# 1        2024
# 2        2024
# 3        2024
# 4        2024
#          ...
# 72863    2024
# 72864    2024
# 72865    2024
# 72866    2024
# 72867    2024
# Name: Year, Length: 72868, dtype: int64>

# %%
df.isna().sum()
# Out:
# Year      0
# Field     0
# Post      0
# Salary    0
# dtype: int64

# %%
df.drop(columns= ['Year'], inplace=True )

# %%
df.isna().sum()
# Out:
# Field     0
# Post      0
# Salary    0
# dtype: int64

# %%
le = LabelEncoder()
df['Post'] = le.fit_transform(df['Post'])
df['Field'] = le.fit_transform(df['Field'])

df.head()
# Out:
#    Field  Post  Salary
# 0      0     4   48206
# 1      0    22   50543
# 2      0    22   11170
# 3      0    41   16489
# 4      0    41   13554

# %%
ss = StandardScaler()

df[['Salary']] = ss.fit_transform(df[['Salary']])

df.head(5)
# Out:
#    Field  Post    Salary
# 0      0     4  0.950499
# 1      0    22  1.083051
# 2      0    22 -1.150144
# 3      0    41 -0.848456
# 4      0    41 -1.014926

# %%
X = df[['Field','Post']]
Y = df['Salary']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y,train_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
print(y_pred)
# Out:
# [ 0.06783947  0.02149219  0.0805423  ... -0.04584949  0.0965733
#  -0.07130239]

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 print(accuracy_score(y_test,y_pred))
#
# File c:\Users\siddh\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
#     219     # the function to delegate validation to the estimator, but we replace
#     220     # the name of the estimator by the name of the function in the error
# ...
